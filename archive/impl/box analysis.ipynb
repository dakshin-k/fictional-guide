# %%
import sqlite3
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

db = sqlite3.connect('fancy-boxes.sqlite')

# %%
db.cursor().execute("SELECT name FROM sqlite_master WHERE type='table'").fetchall()
# Out:
# [('historicals',),
#  ('active_trades',),
#  ('transactions',),
#  ('portfolio_cash',),
#  ('simulation_log',),
#  ('strategy_state',),
#  ('darvas_boxes',),
#  ('sqlite_sequence',)]

# %%
db.cursor().execute("select * from portfolio_cash where ticker = 'IDEA.NS'").fetchall()
# Out:
# [('IDEA.NS', 8.084783313574874, 1)]

# %%
simulation_log = pd.read_sql_query("SELECT * FROM simulation_log where ticker='IDEA.NS'", db)
simulation_log.head(50)
# Out:
#       log_date   ticker  \
# 0   2022-10-04  IDEA.NS
# 1   2022-10-06  IDEA.NS
# 2   2022-10-10  IDEA.NS
# 3   2022-10-10  IDEA.NS
# 4   2022-10-14  IDEA.NS
# 5   2022-10-17  IDEA.NS
# 6   2022-10-17  IDEA.NS
# 7   2022-10-21  IDEA.NS
# 8   2022-10-24  IDEA.NS
# 9   2022-10-25  IDEA.NS
# 10  2022-10-25  IDEA.NS
# 11  2022-11-02  IDEA.NS
# 12  2022-11-04  IDEA.NS
# 13  2022-11-04  IDEA.NS
# 14  2022-11-10  IDEA.NS
# 15  2022-11-11  IDEA.NS
# 16  2022-11-14  IDEA.NS
# 17  2022-11-14  IDEA.NS
# 18  2022-11-22  IDEA.NS
# 19  2022-11-23  IDEA.NS
# 20  2022-11-23  IDEA.NS
# 21  2022-12-01  IDEA.NS
# 22  2022-12-02  IDEA.NS
# 23  2022-12-05  IDEA.NS
# 24  2022-12-05  IDEA.NS
# 25  2022-12-15  IDEA.NS
# 26  2022-12-16  IDEA.NS
# 27  2022-12-20  IDEA.NS
# 28  2022-12-20  IDEA.NS
# 29  2022-12-29  IDEA.NS
# 30  2022-12-30  IDEA.NS
# 31  2023-01-03  IDEA.NS
# 32  2023-01-04  IDEA.NS
# 33  2023-01-04  IDEA.NS
# 34  2023-01-20  IDEA.NS
# 35  2023-01-23  IDEA.NS
# 36  2023-01-23  IDEA.NS
# ...
